# %% [markdown]
# # Import Pandas and read input file

# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df = df. rename(columns={'Postal Code':'PostalCode'})

# %%
df
# Out:
#     PostalCode           Borough  \
# 0          M1A      Not assigned
# 1          M2A      Not assigned
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# ..         ...               ...
# 175        M5Z      Not assigned
# 176        M6Z      Not assigned
# 177        M7Z      Not assigned
# 178        M8Z         Etobicoke
# 179        M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# ...

# %% [markdown]
# # Drop unassigned Neighbourhoods

# %%
df = df[df.Neighbourhood != 'Not assigned']
df
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# ..         ...               ...
# 160        M8X         Etobicoke
# 165        M4Y  Downtown Toronto
# 168        M7Y      East Toronto
# 169        M8Y         Etobicoke
# 178        M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# ...

# %% [markdown]
# # Check DataFrame Shape

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Install Opencage with encrypted key

# %%
pip install opencage
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
from opencage.geocoder import OpenCageGeocode

key = '834a3efd0bd34e5ba8780a0d44404653'
geocoder = OpenCageGeocode(key)

# %%
df
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# ..         ...               ...
# 160        M8X         Etobicoke
# 165        M4Y  Downtown Toronto
# 168        M7Y      East Toronto
# 169        M8Y         Etobicoke
# 178        M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# ...

# %% [markdown]
# # For each row in PostalCode column, extract longitude and latitude, and append to DataFrame - df

# %%
list_lat = [] 
list_long = []
for index, row in df.iterrows():
    Post = row['PostalCode']
    query = str(Post)

    results = geocoder.geocode(query)   
    lat = results[0]['geometry']['lat']
    long = results[0]['geometry']['lng']

    list_lat.append(lat)
    list_long.append(long)

# %%
df['lat'] = list_lat   
df['lon'] = list_long
# Out:
# C:\Users\tandatta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\tandatta\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Display DataFrame df with additional latitude and longitude columns

# %%
df
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# ..         ...               ...
# 160        M8X         Etobicoke
# 165        M4Y  Downtown Toronto
# 168        M7Y      East Toronto
# 169        M8Y         Etobicoke
# 178        M8Z         Etobicoke
#
#                                          Neighbourhood        lat        lon
# 2                                            Parkwoods  49.484606   8.466197
# 3                                     Victoria Village  49.484290   8.467000
# 4                            Regent Park, Harbourfront  45.440588  28.018025
# 5                     Lawrence Manor, Lawrence Heights  53.794164  -1.752006
# 6          Queen's Park, Ontario Provincial Government  44.428198  26.165951
# ..                                                 ...        ...        ...
# ...
